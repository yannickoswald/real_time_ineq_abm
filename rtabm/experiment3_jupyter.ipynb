# %%
#General packages
import os
import numpy as np
from tqdm import tqdm  ### package for progress bars
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
### MODEL 1 infrastructure
import pandas as pd
from model1_class import Model1
from run_enkf import *
### MODEL 2 infrastructure
from model2_class import Model2
#from run_both_models_n_times_and_compute_error import *


#%%
''' this experiment investigate the influence 
of the ensemble size on the ENKF performance '''

##### for this experiment change the test period to a much shorter one
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Assuming 'prepare_enkf', 'prepare_enkf2', 'run_enkf', and 'run_enkf2' are defined elsewhere

class Enkf_experiment3:
    
    def __init__(self, num_agents, macro_state_dim, repetitions, ensemble_sizes):
        self.num_agents = num_agents
        self.macro_state_dim = macro_state_dim
        self.repetitions = repetitions
        self.ensemble_sizes = ensemble_sizes
        self.results = []
        
    def run_experiment(self):
        
        model_params1 = {"population_size": 100,
         "growth_rate": 0.025,
         "b_begin": 1.3,
         "distribution": "Pareto_lognormal",
         "start_year": 1990,
         "uncertainty_para": 0}
        
        model_params2 = {"population_size": 100, 
                        "concavity": 1,
                        "growth_rate": 0.025, 
                        "start_year": 1990,
                        "adaptive_sensitivity": 0.02,
                        "uncertainty_para": 0}
        
        
        for size in self.ensemble_sizes:
            array_of_results_enkf1 = np.zeros((self.repetitions, 1))
            array_of_results_enkf2 = np.zeros((self.repetitions, 1))
            for i in tqdm(range(self.repetitions), desc=f"Ensemble size {size} repetitions"):
                enkf1 = prepare_enkf(Model1,
                                          model_params= model_params1,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                enkf2 = prepare_enkf(Model2, model_params= model_params2,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                
                run_enkf(enkf1, time_horizon=12*3, filter_freq = 10)
                run_enkf(enkf2, time_horizon=12*3, filter_freq = 10)
                array_of_results_enkf1[i, 0] = enkf1.integral_error()
                array_of_results_enkf2[i, 0] = enkf2.integral_error()
                
            self.results.append([f'Ensemble size {size}', array_of_results_enkf1, array_of_results_enkf2])
    
    def plot_results(self, save_fig=False, fig_name='fig6.png'):
        fig, ax = plt.subplots()
        boxplot_artists = []
        positions = np.arange(len(self.results)) * 2
        max_value = -np.inf  # Start with the smallest possible value

        for i, (label, array1, array2) in enumerate(self.results):
            pos = positions[i] + np.array([-0.4, 0.4])
            box1 = ax.boxplot(array1, positions=[pos[0]], widths=0.6, patch_artist=True)
            box2 = ax.boxplot(array2, positions=[pos[1]], widths=0.6, patch_artist=True)
            plt.setp(box1["boxes"], facecolor='lightcoral')
            plt.setp(box1["medians"], color='black')
            plt.setp(box2["boxes"], facecolor='lightblue')
            plt.setp(box2["medians"], color='black')

            # Calculate coefficient of variation
            cv1 = np.std(array1) / np.mean(array1)
            cv2 = np.std(array2) / np.mean(array2)

            # Annotate coefficient of variation below the boxplots
            y_offset = min(np.min(array1), np.min(array2)) - (0.05 * np.abs(min(np.min(array1), np.min(array2))))
            ax.text(pos[0], y_offset, f'CV: {cv1:.2f}', ha='center', va='top', fontsize=8)
            ax.text(pos[1], y_offset, f'CV: {cv2:.2f}', ha='center', va='top', fontsize=8)

            ax.plot(np.random.normal(pos[0], 0.04, size=len(array1)), array1, 'r.', alpha=0.7)
            ax.plot(np.random.normal(pos[1], 0.04, size=len(array2)), array2, 'b.', alpha=0.7)
            if i == 0:
                boxplot_artists.append(box1['boxes'][0])
                boxplot_artists.append(box2['boxes'][0])

            # Update max_value if needed
            max_value = max(max_value, np.max(array1), np.max(array2))
                
        ax.set_xticks(positions)
        ax.set_xticklabels([label for label, _, _ in self.results])
        ax.set_ylabel('Error sum under curve of mean error')
        legend_labels = ['Model1 ENKF Boxplot', 'Model 2 ENKF Boxplot']
        ax.legend(boxplot_artists, legend_labels, title='Legend', loc="upper right", frameon=False)

        # Set y-axis upper limit
        ax.set_ylim(2, max_value+0.5)  # Assuming 3.5 is the lower limit you want

        plt.tight_layout()
        if save_fig:
            plt.savefig(fig_name, dpi=300)
        plt.show()
        
    def compute_elasticity_fit(self):
    
        means1 = np.zeros((len(self.results), 1))
        means2 = np.zeros((len(self.results), 1))

        for idx, (label, array1, array2) in enumerate(self.results):
            means1[idx, 0] = np.mean(array1)
            means2[idx, 0] = np.mean(array2)

        # Transform to log space for linear regression
        log_means1 = np.log(means1)
        log_means2 = np.log(means2)
        log_ensemble_sizes = np.log(self.ensemble_sizes)

        # Perform the linear regression in log space
        # The slope will be the exponent b and the intercept will be log(a)
        slope1, intercept1 = np.polyfit(log_ensemble_sizes, log_means1.ravel(), 1)
        slope2, intercept2 = np.polyfit(log_ensemble_sizes, log_means2.ravel(), 1)

        # Convert intercept into the coefficient a in the original space
        a1 = np.exp(intercept1)
        a2 = np.exp(intercept2)
        
        # Return the coefficients (a, b) for both fits
        return (a1, slope1), (a2, slope2)

# To use the class
num_agents = 100
macro_state_dim = 4
repetitions = 20
ensemble_sizes = [5,10,30,100]

experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
experiment.run_experiment()
experiment.plot_results(save_fig=True)
elasticities = experiment.compute_elasticity_fit()
# Out:
# Ensemble size 5 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.09it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 97.45it/s]
# Ensemble size 5 repetitions:   5%|▌         | 1/20 [00:02<00:52,  2.76s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 14.05it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 86.88it/s]
# Ensemble size 5 repetitions:  10%|█         | 2/20 [00:05<00:53,  2.98s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 15.61it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 86.80it/s]
# Ensemble size 5 repetitions:  15%|█▌        | 3/20 [00:08<00:49,  2.93s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 10.30it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 78.10it/s]
# Ensemble size 5 repetitions:  20%|██        | 4/20 [00:12<00:54,  3.40s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 13.67it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 80.09it/s]
# Ensemble size 5 repetitions:  25%|██▌       | 5/20 [00:16<00:50,  3.34s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.44it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 66.77it/s]
# Ensemble size 5 repetitions:  30%|███       | 6/20 [00:19<00:47,  3.43s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.60it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 75.13it/s]
# Ensemble size 5 repetitions:  35%|███▌      | 7/20 [00:23<00:44,  3.45s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.31it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 82.79it/s]
# Ensemble size 5 repetitions:  40%|████      | 8/20 [00:27<00:42,  3.58s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.98it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 69.45it/s]
# Ensemble size 5 repetitions:  45%|████▌     | 9/20 [00:30<00:38,  3.54s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.96it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 86.36it/s]
# Ensemble size 5 repetitions:  50%|█████     | 10/20 [00:33<00:34,  3.48s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 11.81it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 82.88it/s]
# Ensemble size 5 repetitions:  55%|█████▌    | 11/20 [00:37<00:31,  3.53s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 13.00it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 80.12it/s]
# Ensemble size 5 repetitions:  60%|██████    | 12/20 [00:40<00:28,  3.50s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.34it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 83.31it/s]
# Ensemble size 5 repetitions:  65%|██████▌   | 13/20 [00:44<00:24,  3.51s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 13.67it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 83.09it/s]
# Ensemble size 5 repetitions:  70%|███████   | 14/20 [00:47<00:20,  3.42s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.50it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 80.30it/s]
# Ensemble size 5 repetitions:  75%|███████▌  | 15/20 [00:51<00:17,  3.44s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 12.41it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 76.85it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 11.89it/s]/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 78.43it/s]
# Ensemble size 5 repetitions:  85%|████████▌ | 17/20 [00:58<00:10,  3.52s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 11.26it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 69.93it/s]
# Ensemble size 5 repetitions:  90%|█████████ | 18/20 [01:02<00:07,  3.63s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 11.93it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 66.30it/s]
# Ensemble size 5 repetitions:  95%|█████████▌| 19/20 [01:05<00:03,  3.66s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 10.54it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 58.03it/s]
# Ensemble size 5 repetitions: 100%|██████████| 20/20 [01:10<00:00,  3.51s/it]
# Ensemble size 10 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:06<00:00,  5.16it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.07it/s]
# Ensemble size 10 repetitions:   5%|▌         | 1/20 [00:08<02:35,  8.21s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  5.09it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:01<00:00, 35.56it/s]
# Ensemble size 10 repetitions:  10%|█         | 2/20 [00:16<02:29,  8.30s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.84it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 39.63it/s]
# Ensemble size 10 repetitions:  15%|█▌        | 3/20 [00:25<02:28,  8.75s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.72it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.71it/s]
# Ensemble size 10 repetitions:  20%|██        | 4/20 [00:32<02:05,  7.85s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:06<00:00,  5.77it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 44.49it/s]
# Ensemble size 10 repetitions:  25%|██▌       | 5/20 [00:39<01:54,  7.65s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.66it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.06it/s]
# Ensemble size 10 repetitions:  30%|███       | 6/20 [00:46<01:41,  7.28s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.41it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 40.72it/s]
# Ensemble size 10 repetitions:  35%|███▌      | 7/20 [00:52<01:32,  7.12s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.73it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.44it/s]
# Ensemble size 10 repetitions:  40%|████      | 8/20 [00:59<01:22,  6.90s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.34it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.89it/s]
# Ensemble size 10 repetitions:  45%|████▌     | 9/20 [01:06<01:16,  6.92s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.40it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 40.95it/s]
# Ensemble size 10 repetitions:  50%|█████     | 10/20 [01:13<01:08,  6.87s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.48it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 44.76it/s]
# Ensemble size 10 repetitions:  55%|█████▌    | 11/20 [01:19<01:01,  6.80s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.40it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 39.86it/s]
# Ensemble size 10 repetitions:  60%|██████    | 12/20 [01:26<00:54,  6.79s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.72it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 40.00it/s]
# Ensemble size 10 repetitions:  65%|██████▌   | 13/20 [01:33<00:46,  6.70s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.06it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.83it/s]
# Ensemble size 10 repetitions:  70%|███████   | 14/20 [01:40<00:40,  6.81s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.38it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 47.43it/s]
# Ensemble size 10 repetitions:  75%|███████▌  | 15/20 [01:46<00:33,  6.76s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.34it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 41.34it/s]
# Ensemble size 10 repetitions:  80%|████████  | 16/20 [01:53<00:27,  6.77s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.43it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 42.22it/s]
# Ensemble size 10 repetitions:  85%|████████▌ | 17/20 [02:00<00:20,  6.74s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.29it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 42.83it/s]
# Ensemble size 10 repetitions:  90%|█████████ | 18/20 [02:07<00:13,  6.77s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.41it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 39.31it/s]
# Ensemble size 10 repetitions:  95%|█████████▌| 19/20 [02:13<00:06,  6.78s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  7.09it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:00<00:00, 42.15it/s]
# Ensemble size 10 repetitions: 100%|██████████| 20/20 [02:20<00:00,  7.01s/it]
# Ensemble size 30 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.50it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 15.53it/s]
# Ensemble size 30 repetitions:   5%|▌         | 1/20 [00:17<05:29, 17.32s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:15<00:00,  2.37it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.49it/s]
# Ensemble size 30 repetitions:  10%|█         | 2/20 [00:35<05:18, 17.67s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.51it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:01<00:00, 18.08it/s]
# Ensemble size 30 repetitions:  15%|█▌        | 3/20 [00:52<04:54, 17.29s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:13<00:00,  2.58it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 17.74it/s]
# Ensemble size 30 repetitions:  20%|██        | 4/20 [01:08<04:31, 16.98s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.49it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 14.57it/s]
# Ensemble size 30 repetitions:  25%|██▌       | 5/20 [01:26<04:18, 17.24s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.48it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 15.80it/s]
# Ensemble size 30 repetitions:  30%|███       | 6/20 [01:43<04:01, 17.27s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:15<00:00,  2.38it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 17.13it/s]
# Ensemble size 30 repetitions:  35%|███▌      | 7/20 [02:01<03:46, 17.44s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:15<00:00,  2.36it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.19it/s]
# Ensemble size 30 repetitions:  40%|████      | 8/20 [02:19<03:31, 17.66s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.41it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.07it/s]
# Ensemble size 30 repetitions:  45%|████▌     | 9/20 [02:37<03:14, 17.69s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:15<00:00,  2.36it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.50it/s]
# Ensemble size 30 repetitions:  50%|█████     | 10/20 [02:55<02:58, 17.89s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.42it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 15.50it/s]
# Ensemble size 30 repetitions:  55%|█████▌    | 11/20 [03:13<02:40, 17.87s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.44it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.82it/s]
# Ensemble size 30 repetitions:  60%|██████    | 12/20 [03:31<02:22, 17.78s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:15<00:00,  2.32it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 14.94it/s]
# Ensemble size 30 repetitions:  65%|██████▌   | 13/20 [03:49<02:05, 17.99s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:17<00:00,  2.11it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:01<00:00, 19.08it/s]
# Ensemble size 30 repetitions:  70%|███████   | 14/20 [04:09<01:50, 18.49s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:13<00:00,  2.58it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.79it/s]
# Ensemble size 30 repetitions:  75%|███████▌  | 15/20 [04:25<01:29, 17.92s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:16<00:00,  2.13it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 11.32it/s]
# Ensemble size 30 repetitions:  80%|████████  | 16/20 [04:46<01:14, 18.73s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:19<00:00,  1.82it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:03<00:00, 11.81it/s]
# Ensemble size 30 repetitions:  85%|████████▌ | 17/20 [05:10<01:00, 20.23s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.54it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 16.95it/s]
# Ensemble size 30 repetitions:  90%|█████████ | 18/20 [05:27<00:38, 19.26s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:14<00:00,  2.52it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:01<00:00, 18.25it/s]
# Ensemble size 30 repetitions:  95%|█████████▌| 19/20 [05:43<00:18, 18.51s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:17<00:00,  2.10it/s]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:02<00:00, 17.75it/s]
# Ensemble size 30 repetitions: 100%|██████████| 20/20 [06:03<00:00, 18.18s/it]
# Ensemble size 100 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:50<00:00,  1.41s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.93it/s]
# Ensemble size 100 repetitions:   5%|▌         | 1/20 [00:59<18:55, 59.77s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:51<00:00,  1.42s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.85it/s]
# Ensemble size 100 repetitions:  10%|█         | 2/20 [02:00<18:06, 60.37s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:49<00:00,  1.38s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.71it/s]
# Ensemble size 100 repetitions:  15%|█▌        | 3/20 [02:59<16:58, 59.88s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [01:02<00:00,  1.73s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:08<00:00,  4.09it/s]
# Ensemble size 100 repetitions:  20%|██        | 4/20 [04:13<17:22, 65.14s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [01:01<00:00,  1.70s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:08<00:00,  4.20it/s]
# Ensemble size 100 repetitions:  25%|██▌       | 5/20 [05:25<16:57, 67.85s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:53<00:00,  1.49s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:08<00:00,  4.33it/s]
# Ensemble size 100 repetitions:  30%|███       | 6/20 [06:30<15:33, 66.64s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:54<00:00,  1.53s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:08<00:00,  4.36it/s]
# Ensemble size 100 repetitions:  35%|███▌      | 7/20 [07:35<14:19, 66.12s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:51<00:00,  1.43s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.83it/s]
# Ensemble size 100 repetitions:  40%|████      | 8/20 [08:36<12:53, 64.49s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:52<00:00,  1.46s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:06<00:00,  5.37it/s]
# Ensemble size 100 repetitions:  45%|████▌     | 9/20 [09:37<11:38, 63.51s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:45<00:00,  1.26s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.10it/s]
# Ensemble size 100 repetitions:  50%|█████     | 10/20 [10:30<10:01, 60.18s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:44<00:00,  1.23s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.11it/s]
# Ensemble size 100 repetitions:  55%|█████▌    | 11/20 [11:22<08:39, 57.68s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:43<00:00,  1.20s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:06<00:00,  5.84it/s]
# Ensemble size 100 repetitions:  60%|██████    | 12/20 [12:13<07:25, 55.68s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:48<00:00,  1.34s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.72it/s]
# Ensemble size 100 repetitions:  65%|██████▌   | 13/20 [13:10<06:33, 56.24s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:49<00:00,  1.38s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.88it/s]
# Ensemble size 100 repetitions:  70%|███████   | 14/20 [14:09<05:42, 57.07s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [01:03<00:00,  1.76s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:09<00:00,  3.97it/s]
# Ensemble size 100 repetitions:  75%|███████▌  | 15/20 [15:24<05:12, 62.42s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [01:07<00:00,  1.88s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:07<00:00,  4.75it/s]
# Ensemble size 100 repetitions:  80%|████████  | 16/20 [16:41<04:27, 66.89s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:43<00:00,  1.21s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.25it/s]
# Ensemble size 100 repetitions:  85%|████████▌ | 17/20 [17:33<03:07, 62.34s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:42<00:00,  1.17s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.13it/s]
# Ensemble size 100 repetitions:  90%|█████████ | 18/20 [18:23<01:57, 58.51s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:42<00:00,  1.18s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.03it/s]
# Ensemble size 100 repetitions:  95%|█████████▌| 19/20 [19:13<00:55, 55.94s/it]c:\Users\y-osw\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:42<00:00,  1.17s/it]
# Iterations ENKF Model 1: 100%|██████████| 36/36 [00:05<00:00,  6.17it/s]
# Ensemble size 100 repetitions: 100%|██████████| 20/20 [20:02<00:00, 60.13s/it]
