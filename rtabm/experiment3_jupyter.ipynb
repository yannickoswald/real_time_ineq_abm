# %%
#General packages
import os
import numpy as np
from tqdm import tqdm  ### package for progress bars
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
### MODEL 1 infrastructure
import pandas as pd
from model1_class import Model1
from run_enkf import *
### MODEL 2 infrastructure
from model2_class import Model2
#from run_both_models_n_times_and_compute_error import *


#%%
''' this experiment investigate the influence 
of the ensemble size on the ENKF performance '''

##### for this experiment change the test period to a much shorter one
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Assuming 'prepare_enkf', 'prepare_enkf2', 'run_enkf', and 'run_enkf2' are defined elsewhere

class Enkf_experiment3:
    
    def __init__(self, num_agents, macro_state_dim, repetitions, ensemble_sizes):
        self.num_agents = num_agents
        self.macro_state_dim = macro_state_dim
        self.repetitions = repetitions
        self.ensemble_sizes = ensemble_sizes
        self.results = []
        
    def run_experiment(self, start_year, end_year):
        
        model_params1 = {"population_size": 100,
         "growth_rate": 0.025,
         "b_begin": 1.3,
         "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
         "start_year": start_year,
         "uncertainty_para": 0}
        
        
        model_params2 = {"population_size": 100, 
                "concavity": 1,
                "growth_rate": 0.025, 
                "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
                "start_year": start_year,
                "adaptive_sensitivity": 0.02,
                "uncertainty_para": 0}

        
        for size in self.ensemble_sizes:
            array_of_results_enkf1 = np.zeros((self.repetitions, 1))
            array_of_results_enkf2 = np.zeros((self.repetitions, 1))
            for i in tqdm(range(self.repetitions), desc=f"Ensemble size {size} repetitions"):
                enkf1 = prepare_enkf(Model1,
                                          model_params= model_params1,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                enkf2 = prepare_enkf(Model2, model_params= model_params2,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                
                run_enkf(enkf1, start_year=start_year,end_year=end_year, filter_freq = 10)
                run_enkf(enkf2,  start_year=start_year,end_year=end_year, filter_freq = 10)
                array_of_results_enkf1[i, 0] = enkf1.integral_error()
                array_of_results_enkf2[i, 0] = enkf2.integral_error()
                
            self.results.append([f'Ensemble size {size}', array_of_results_enkf1, array_of_results_enkf2])
    
    def plot_results(self, save_fig=False, fig_name='fig7.png'):
        fig, ax = plt.subplots()
        boxplot_artists = []
        positions = np.arange(len(self.results)) * 2
        max_value = -np.inf  # Start with the smallest possible value

        for i, (label, array1, array2) in enumerate(self.results):
            pos = positions[i] + np.array([-0.4, 0.4])
            box1 = ax.boxplot(array1, positions=[pos[0]], widths=0.6, patch_artist=True)
            box2 = ax.boxplot(array2, positions=[pos[1]], widths=0.6, patch_artist=True)
            plt.setp(box1["boxes"], facecolor='lightcoral')
            plt.setp(box1["medians"], color='black')
            plt.setp(box2["boxes"], facecolor='lightblue')
            plt.setp(box2["medians"], color='black')

            # Calculate coefficient of variation
            cv1 = np.std(array1) / np.mean(array1)
            cv2 = np.std(array2) / np.mean(array2)

            # Annotate coefficient of variation below the boxplots
            y_offset = min(np.min(array1), np.min(array2)) - (0.05 * np.abs(min(np.min(array1), np.min(array2))))
            ax.text(pos[0], y_offset, f'CV: {cv1:.2f}', ha='center', va='top', fontsize=8)
            ax.text(pos[1], y_offset, f'CV: {cv2:.2f}', ha='center', va='top', fontsize=8)

            ax.plot(np.random.normal(pos[0], 0.04, size=len(array1)), array1, 'r.', alpha=0.7)
            ax.plot(np.random.normal(pos[1], 0.04, size=len(array2)), array2, 'b.', alpha=0.7)
            if i == 0:
                boxplot_artists.append(box1['boxes'][0])
                boxplot_artists.append(box2['boxes'][0])

            # Update max_value if needed
            max_value = max(max_value, np.max(array1), np.max(array2))
                
        ax.set_xticks(positions)
        ax.set_xticklabels([label for label, _, _ in self.results])
        ax.set_ylabel('Error sum under curve of mean error', fontsize=12)
        legend_labels = ['Model 1 ENKF Boxplot', 'Model 2 ENKF Boxplot']
        ax.legend(boxplot_artists, legend_labels, title='Legend', loc="upper right", frameon=False)

        # Set y-axis upper limit
        ax.set_ylim(2, max_value+0.5)  # Assuming 3.5 is the lower limit you want

        plt.tight_layout()
        if save_fig:
            plt.savefig(fig_name, dpi=300)
        plt.show()
        
    def compute_elasticity_fit(self):
    
        means1 = np.zeros((len(self.results), 1))
        means2 = np.zeros((len(self.results), 1))

        for idx, (label, array1, array2) in enumerate(self.results):
            means1[idx, 0] = np.mean(array1)
            means2[idx, 0] = np.mean(array2)

        # Transform to log space for linear regression
        log_means1 = np.log(means1)
        log_means2 = np.log(means2)
        log_ensemble_sizes = np.log(self.ensemble_sizes)

        # Perform the linear regression in log space
        # The slope will be the exponent b and the intercept will be log(a)
        slope1, intercept1 = np.polyfit(log_ensemble_sizes, log_means1.ravel(), 1)
        slope2, intercept2 = np.polyfit(log_ensemble_sizes, log_means2.ravel(), 1)

        # Convert intercept into the coefficient a in the original space
        a1 = np.exp(intercept1)
        a2 = np.exp(intercept2)
        
        # Return the coefficients (a, b) for both fits
        return (a1, slope1), (a2, slope2)

# To use the class
num_agents = 100
start_year = 1990
end_year = 1993
macro_state_dim = 4
repetitions = 20
ensemble_sizes = [5,10,30,100]

experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
experiment.run_experiment(start_year=start_year, end_year=end_year)
experiment.plot_results(save_fig=True)
elasticities = experiment.compute_elasticity_fit()
# Out:
# Ensemble size 5 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 189.34it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 127.31it/s]
# Ensemble size 5 repetitions:   5%|▌         | 1/20 [00:04<01:34,  4.96s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 134.64it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 24.63it/s]
# Ensemble size 5 repetitions:  10%|█         | 2/20 [00:11<01:42,  5.68s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 41.69it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 29.15it/s]
# Ensemble size 5 repetitions:  15%|█▌        | 3/20 [00:25<02:46,  9.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 42.93it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 25.55it/s]
# Ensemble size 5 repetitions:  20%|██        | 4/20 [00:40<03:09, 11.82s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 44.02it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 26.39it/s]
# Ensemble size 5 repetitions:  25%|██▌       | 5/20 [00:55<03:12, 12.87s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 55.96it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 28.21it/s]
# Ensemble size 5 repetitions:  30%|███       | 6/20 [01:09<03:06, 13.35s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 47.54it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 25.80it/s]
# Ensemble size 5 repetitions:  35%|███▌      | 7/20 [01:24<03:00, 13.89s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 39.40it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 25.59it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 45.98it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 26.72it/s]
# Ensemble size 5 repetitions:  45%|████▌     | 9/20 [01:53<02:35, 14.11s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 48.52it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 27.69it/s]
# Ensemble size 5 repetitions:  50%|█████     | 10/20 [02:08<02:23, 14.33s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 41.96it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 26.68it/s]
# Ensemble size 5 repetitions:  55%|█████▌    | 11/20 [02:22<02:08, 14.25s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 43.46it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 26.79it/s]
# Ensemble size 5 repetitions:  60%|██████    | 12/20 [02:37<01:55, 14.41s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 48.85it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 26.93it/s]
# Ensemble size 5 repetitions:  65%|██████▌   | 13/20 [02:51<01:40, 14.34s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 43.85it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 28.31it/s]
# Ensemble size 5 repetitions:  70%|███████   | 14/20 [03:05<01:26, 14.36s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 47.01it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 27.20it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 40.48it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 27.68it/s]
# Ensemble size 5 repetitions:  80%|████████  | 16/20 [03:34<00:57, 14.41s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 181.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 128.56it/s]
# Ensemble size 5 repetitions:  85%|████████▌ | 17/20 [03:48<00:42, 14.16s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 191.62it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 127.27it/s]
# Ensemble size 5 repetitions:  90%|█████████ | 18/20 [03:52<00:22, 11.15s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 38.87it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 26.49it/s]
# Ensemble size 5 repetitions:  95%|█████████▌| 19/20 [03:59<00:10, 10.03s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 49.71it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 27.55it/s]
# Ensemble size 5 repetitions: 100%|██████████| 20/20 [04:14<00:00, 12.74s/it]
# Ensemble size 10 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 24.37it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 14.19it/s]
# Ensemble size 10 repetitions:   5%|▌         | 1/20 [00:29<09:15, 29.23s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 27.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 15.00it/s]
# Ensemble size 10 repetitions:  10%|█         | 2/20 [00:59<08:57, 29.84s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 25.74it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 14.16it/s]
# Ensemble size 10 repetitions:  15%|█▌        | 3/20 [01:30<08:34, 30.29s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 25.02it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 13.99it/s]
# Ensemble size 10 repetitions:  20%|██        | 4/20 [02:00<08:05, 30.31s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>:  98%|█████████▊| 47/48 [00:00<00:00, 84.93it/s]
# Ensemble size 10 repetitions:  20%|██        | 4/20 [02:17<09:10, 34.41s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 160
#     157 ensemble_sizes = [5,10,30,100]
#     159 experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
# --> 160 experiment.run_experiment(start_year=start_year, end_year=end_year)
#     161 experiment.plot_results(save_fig=True)
#     162 elasticities = experiment.compute_elasticity_fit()
#
# Cell In[3], line 71, in Enkf_experiment3.run_experiment(self, start_year, end_year)
#      59 enkf1 = prepare_enkf(Model1,
#      60                           model_params= model_params1,
#      61                           ensemble_size = size,
#      62                           macro_state_dim = self.macro_state_dim,
#      63                           filter_freq = 10,
#      64                           uncertainty_obs = 0.05)
#      65 enkf2 = prepare_enkf(Model2, model_params= model_params2,
#      66                           ensemble_size = size,
#      67                           macro_state_dim = self.macro_state_dim,
#      68                           filter_freq = 10,
#      69                           uncertainty_obs = 0.05)
# ---> 71 run_enkf(enkf1, start_year=start_year,end_year=end_year, filter_freq = 10)
#      72 run_enkf(enkf2,  start_year=start_year,end_year=end_year, filter_freq = 10)
#      73 array_of_results_enkf1[i, 0] = enkf1.integral_error()
#
# File c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\run_enkf.py:59, in run_enkf(enkf, start_year, end_year, filter_freq)
#      54 for i in tqdm(range(time_horizon), desc="Iterations ENKF " + str(enkf.modelclass)):
#      55 #for i in range(time_horizon):
#      56     #if i == 1: break
#      57     ### set update to false or true
#      58     if i % filter_freq != 0 or i == 0:
# ---> 59         enkf.step(update = False)
#      60         #test = enkf.plot_macro_state(False)
#      61     else:
#      62         enkf.step(update = True)
#
# File c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\enkf_yo.py:854, in EnsembleKalmanFilter.step(self, update)
#     851 self.update_decision = update ## var to pass on to other methods
#     853                      ##>>>??? for decision making
# --> 854 self.predict()
#     855 self.time = self.time + 1
#     856 self.set_current_obs()
#
# File c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\enkf_yo.py:153, in EnsembleKalmanFilter.predict(self)
#     146 """
#     147 Step the model forward by one time-step to produce a prediction.
#     148 Params:
#     149 Returns:
#     150     None
#     151 """
#     152 for i in range(self.ensemble_size):
# --> 153     self.models[i].step()
#
# File c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\model1_class.py:205, in Model1.step(self)
#     203 self.sum_power = self.sum_of_agent_power()
#     204 self.grow()
# --> 205 self.distribute_wealth()
#     206 self.determine_agent_trajectories()
#     207 a = find_wealth_groups(self.agents, self.economy_wealth)
#
# File c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\model1_class.py:182, in Model1.distribute_wealth(self)
#     176 ''' This method chooses an agent each around and distributes all wealth, in n-rounds,
#     177 where n is the number of wealth-increments (an arbitrary number that has to be chosen
#     178  but we usually set equal to the number of agents, so that there are as
#     179  many chances to get new wealth as as there are agents).'''
#     181 for increment in range(self.increments):
# --> 182     agent_j = self.choose_agent()
#     183     agent_j.wealth = agent_j.wealth + (self.new_wealth / self.increments)
#
# File c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\model1_class.py:162, in Model1.choose_agent(self)
#     160 #print(f"sum of weights {sum(weights)}")
#     161 self.weightshistory.append(weights)
# --> 162 return random.choices(self.agents, weights, k=1)[0]
#
# File c:\Users\yoswald\AppData\Local\Programs\Python\Python311\Lib\random.py:495, in Random.choices(self, population, weights, cum_weights, k)
#     493     return [population[floor(random() * n)] for i in _repeat(None, k)]
#     494 try:
# --> 495     cum_weights = list(_accumulate(weights))
#     496 except TypeError:
#     497     if not isinstance(weights, int):
#
# KeyboardInterrupt:

# %%
# print the elasticities
print(f"Model 1: a={elasticities[0][0]:.2f}, b={elasticities[0][1]:.2f}")
print(f"Model 2: a={elasticities[1][0]:.2f}, b={elasticities[1][1]:.2f}")
# Out:
# Model 1: a=11.15, b=-0.19
# Model 2: a=10.15, b=-0.13
