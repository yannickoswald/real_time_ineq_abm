# %%
#General packages
import os
import numpy as np
from tqdm import tqdm  ### package for progress bars
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
### MODEL 1 infrastructure
import pandas as pd
from model1_class import Model1
from run_enkf import *
### MODEL 2 infrastructure
from model2_class import Model2
#from run_both_models_n_times_and_compute_error import *


#%%
''' this experiment investigate the influence 
of the ensemble size on the ENKF performance '''

##### for this experiment change the test period to a much shorter one
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Assuming 'prepare_enkf', 'prepare_enkf2', 'run_enkf', and 'run_enkf2' are defined elsewhere

class Enkf_experiment3:
    
    def __init__(self, num_agents, macro_state_dim, repetitions, ensemble_sizes):
        self.num_agents = num_agents
        self.macro_state_dim = macro_state_dim
        self.repetitions = repetitions
        self.ensemble_sizes = ensemble_sizes
        self.results = []
        
    def run_experiment(self, start_year, end_year):
        
        model_params1 = {"population_size": 100,
         "growth_rate": 0.025,
         "b_begin": 1.3,
         "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
         "start_year": start_year,
         "uncertainty_para": 0}
        
        
        model_params2 = {"population_size": 100, 
                "concavity": 1,
                "growth_rate": 0.025, 
                "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
                "start_year": start_year,
                "adaptive_sensitivity": 0.02,
                "uncertainty_para": 0}

        
        for size in self.ensemble_sizes:
            array_of_results_enkf1 = np.zeros((self.repetitions, 1))
            array_of_results_enkf2 = np.zeros((self.repetitions, 1))
            for i in tqdm(range(self.repetitions), desc=f"Ensemble size {size} repetitions"):
                enkf1 = prepare_enkf(Model1,
                                          model_params= model_params1,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                enkf2 = prepare_enkf(Model2, model_params= model_params2,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                
                run_enkf(enkf1, start_year=start_year,end_year=end_year, filter_freq = 10)
                run_enkf(enkf2,  start_year=start_year,end_year=end_year, filter_freq = 10)
                array_of_results_enkf1[i, 0] = enkf1.integral_error()
                array_of_results_enkf2[i, 0] = enkf2.integral_error()
                
            self.results.append([f'Ensemble size {size}', array_of_results_enkf1, array_of_results_enkf2])
    
    def plot_results(self, save_fig=False, fig_name='fig7.png'):
        fig, ax = plt.subplots()
        boxplot_artists = []
        positions = np.arange(len(self.results)) * 2
        max_value = -np.inf  # Start with the smallest possible value

        for i, (label, array1, array2) in enumerate(self.results):
            pos = positions[i] + np.array([-0.4, 0.4])
            box1 = ax.boxplot(array1, positions=[pos[0]], widths=0.6, patch_artist=True)
            box2 = ax.boxplot(array2, positions=[pos[1]], widths=0.6, patch_artist=True)
            plt.setp(box1["boxes"], facecolor='lightcoral')
            plt.setp(box1["medians"], color='black')
            plt.setp(box2["boxes"], facecolor='lightblue')
            plt.setp(box2["medians"], color='black')

            # Calculate coefficient of variation
            cv1 = np.std(array1) / np.mean(array1)
            cv2 = np.std(array2) / np.mean(array2)

            # Annotate coefficient of variation below the boxplots
            y_offset = min(np.min(array1), np.min(array2)) - (0.05 * np.abs(min(np.min(array1), np.min(array2))))
            ax.text(pos[0], y_offset, f'CV: {cv1:.2f}', ha='center', va='top', fontsize=8)
            ax.text(pos[1], y_offset, f'CV: {cv2:.2f}', ha='center', va='top', fontsize=8)

            ax.plot(np.random.normal(pos[0], 0.04, size=len(array1)), array1, 'r.', alpha=0.7)
            ax.plot(np.random.normal(pos[1], 0.04, size=len(array2)), array2, 'b.', alpha=0.7)
            if i == 0:
                boxplot_artists.append(box1['boxes'][0])
                boxplot_artists.append(box2['boxes'][0])

            # Update max_value if needed
            max_value = max(max_value, np.max(array1), np.max(array2))
                
        ax.set_xticks(positions)
        ax.set_xticklabels([label for label, _, _ in self.results])
        ax.set_ylabel('Error sum under curve of mean error', fontsize=12)
        legend_labels = ['Model 1 ENKF Boxplot', 'Model 2 ENKF Boxplot']
        ax.legend(boxplot_artists, legend_labels, title='Legend', loc="upper right", frameon=False)

        # Set y-axis upper limit
        ax.set_ylim(2, max_value+0.5)  # Assuming 3.5 is the lower limit you want

        plt.tight_layout()
        if save_fig:
            plt.savefig(fig_name, dpi=300)
        plt.show()
        
    def compute_elasticity_fit(self):
    
        means1 = np.zeros((len(self.results), 1))
        means2 = np.zeros((len(self.results), 1))

        for idx, (label, array1, array2) in enumerate(self.results):
            means1[idx, 0] = np.mean(array1)
            means2[idx, 0] = np.mean(array2)

        # Transform to log space for linear regression
        log_means1 = np.log(means1)
        log_means2 = np.log(means2)
        log_ensemble_sizes = np.log(self.ensemble_sizes)

        # Perform the linear regression in log space
        # The slope will be the exponent b and the intercept will be log(a)
        slope1, intercept1 = np.polyfit(log_ensemble_sizes, log_means1.ravel(), 1)
        slope2, intercept2 = np.polyfit(log_ensemble_sizes, log_means2.ravel(), 1)

        # Convert intercept into the coefficient a in the original space
        a1 = np.exp(intercept1)
        a2 = np.exp(intercept2)
        
        # Return the coefficients (a, b) for both fits
        return (a1, slope1), (a2, slope2)

# To use the class
num_agents = 100
start_year = 1990
end_year = 1993
macro_state_dim = 4
repetitions = 20
ensemble_sizes = [5,10,30,100]

experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
experiment.run_experiment(start_year=start_year, end_year=end_year)
experiment.plot_results(save_fig=True)
elasticities = experiment.compute_elasticity_fit()
# Out:
# Ensemble size 5 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 176.14it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 108.35it/s]
# Ensemble size 5 repetitions:   5%|▌         | 1/20 [00:01<00:29,  1.55s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 175.55it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 117.83it/s]
# Ensemble size 5 repetitions:  10%|█         | 2/20 [00:03<00:27,  1.54s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 137.91it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 117.32it/s]
# Ensemble size 5 repetitions:  15%|█▌        | 3/20 [00:04<00:26,  1.55s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 183.26it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 115.09it/s]
# Ensemble size 5 repetitions:  20%|██        | 4/20 [00:06<00:24,  1.54s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 158.03it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 99.41it/s]
# Ensemble size 5 repetitions:  25%|██▌       | 5/20 [00:07<00:23,  1.56s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 118.55it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 119.11it/s]
# Ensemble size 5 repetitions:  30%|███       | 6/20 [00:09<00:22,  1.61s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 182.42it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 120.90it/s]
# Ensemble size 5 repetitions:  35%|███▌      | 7/20 [00:10<00:20,  1.54s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 191.61it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 102.65it/s]
# Ensemble size 5 repetitions:  40%|████      | 8/20 [00:12<00:18,  1.52s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 186.05it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 122.76it/s]
# Ensemble size 5 repetitions:  45%|████▌     | 9/20 [00:13<00:16,  1.48s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 187.32it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.76it/s]
# Ensemble size 5 repetitions:  50%|█████     | 10/20 [00:15<00:14,  1.45s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 139.78it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 121.16it/s]
# Ensemble size 5 repetitions:  55%|█████▌    | 11/20 [00:16<00:13,  1.46s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 181.33it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 127.10it/s]
# Ensemble size 5 repetitions:  60%|██████    | 12/20 [00:17<00:11,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 186.61it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 123.03it/s]
# Ensemble size 5 repetitions:  65%|██████▌   | 13/20 [00:19<00:09,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 144.54it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.35it/s]
# Ensemble size 5 repetitions:  70%|███████   | 14/20 [00:20<00:08,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 184.87it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.57it/s]
# Ensemble size 5 repetitions:  75%|███████▌  | 15/20 [00:22<00:07,  1.42s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 181.72it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 124.40it/s]
# Ensemble size 5 repetitions:  80%|████████  | 16/20 [00:23<00:05,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 140.59it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 131.06it/s]
# Ensemble size 5 repetitions:  85%|████████▌ | 17/20 [00:25<00:04,  1.45s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 197.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 124.01it/s]
# Ensemble size 5 repetitions:  90%|█████████ | 18/20 [00:26<00:02,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 132.53it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.30it/s]
# Ensemble size 5 repetitions:  95%|█████████▌| 19/20 [00:28<00:01,  1.45s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 181.04it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 124.44it/s]
# Ensemble size 5 repetitions: 100%|██████████| 20/20 [00:29<00:00,  1.47s/it]
# Ensemble size 10 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 86.15it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.27it/s]
# Ensemble size 10 repetitions:   5%|▌         | 1/20 [00:02<00:53,  2.81s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 101.87it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 61.59it/s]
# Ensemble size 10 repetitions:  10%|█         | 2/20 [00:05<00:50,  2.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 77.95it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 61.51it/s]
# Ensemble size 10 repetitions:  15%|█▌        | 3/20 [00:08<00:48,  2.88s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 84.96it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 63.54it/s]
# Ensemble size 10 repetitions:  20%|██        | 4/20 [00:11<00:46,  2.92s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 98.98it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 60.19it/s]
# Ensemble size 10 repetitions:  25%|██▌       | 5/20 [00:14<00:43,  2.89s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 96.38it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 55.71it/s]
# Ensemble size 10 repetitions:  30%|███       | 6/20 [00:17<00:41,  2.94s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 84.02it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 61.66it/s]
# Ensemble size 10 repetitions:  35%|███▌      | 7/20 [00:20<00:38,  2.95s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 85.93it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 62.62it/s]
# Ensemble size 10 repetitions:  40%|████      | 8/20 [00:23<00:35,  2.93s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 106.91it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 65.58it/s]
# Ensemble size 10 repetitions:  45%|████▌     | 9/20 [00:26<00:31,  2.88s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 83.42it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 63.24it/s]
# Ensemble size 10 repetitions:  50%|█████     | 10/20 [00:29<00:29,  2.91s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 87.19it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 61.66it/s]
# Ensemble size 10 repetitions:  55%|█████▌    | 11/20 [00:32<00:26,  2.93s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 104.26it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 65.82it/s]
# Ensemble size 10 repetitions:  60%|██████    | 12/20 [00:34<00:23,  2.90s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 83.43it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 67.54it/s]
# Ensemble size 10 repetitions:  65%|██████▌   | 13/20 [00:37<00:20,  2.92s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 88.84it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 67.63it/s]
# Ensemble size 10 repetitions:  70%|███████   | 14/20 [00:40<00:17,  2.91s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 101.49it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 58.78it/s]
# Ensemble size 10 repetitions:  75%|███████▌  | 15/20 [00:43<00:14,  2.92s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 104.07it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 67.35it/s]
# Ensemble size 10 repetitions:  80%|████████  | 16/20 [00:46<00:11,  2.93s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 83.17it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 66.25it/s]
# Ensemble size 10 repetitions:  85%|████████▌ | 17/20 [00:49<00:08,  2.96s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 87.36it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 66.53it/s]
# Ensemble size 10 repetitions:  90%|█████████ | 18/20 [00:52<00:05,  2.96s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 99.09it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 66.22it/s]
# Ensemble size 10 repetitions:  95%|█████████▌| 19/20 [00:55<00:02,  2.94s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 85.61it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 65.88it/s]
# Ensemble size 10 repetitions: 100%|██████████| 20/20 [00:58<00:00,  2.93s/it]
# Ensemble size 30 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 32.96it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.20it/s]
# Ensemble size 30 repetitions:   5%|▌         | 1/20 [00:08<02:46,  8.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.26it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.30it/s]
# Ensemble size 30 repetitions:  10%|█         | 2/20 [00:18<02:48,  9.36s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.88it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.57it/s]
# Ensemble size 30 repetitions:  15%|█▌        | 3/20 [00:28<02:40,  9.45s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.86it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.76it/s]
# Ensemble size 30 repetitions:  20%|██        | 4/20 [00:37<02:31,  9.49s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.26it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.32it/s]
# Ensemble size 30 repetitions:  25%|██▌       | 5/20 [00:47<02:24,  9.66s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.21it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.90it/s]
# Ensemble size 30 repetitions:  30%|███       | 6/20 [00:57<02:16,  9.77s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.28it/s]
# Ensemble size 30 repetitions:  35%|███▌      | 7/20 [01:07<02:06,  9.72s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 35.25it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.12it/s]
# Ensemble size 30 repetitions:  40%|████      | 8/20 [01:16<01:56,  9.70s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 32.39it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:05<00:00,  9.19it/s]
# Ensemble size 30 repetitions:  45%|████▌     | 9/20 [01:30<02:00, 10.94s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.95it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.81it/s]
# Ensemble size 30 repetitions:  50%|█████     | 10/20 [01:42<01:52, 11.28s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 32.88it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 20.99it/s]
# Ensemble size 30 repetitions:  55%|█████▌    | 11/20 [01:53<01:39, 11.07s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.23it/s]
# Ensemble size 30 repetitions:  60%|██████    | 12/20 [02:03<01:27, 10.88s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.90it/s]
# Ensemble size 30 repetitions:  65%|██████▌   | 13/20 [02:13<01:14, 10.70s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.92it/s]
# Ensemble size 30 repetitions:  70%|███████   | 14/20 [02:25<01:05, 10.86s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.12it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.09it/s]
# Ensemble size 30 repetitions:  75%|███████▌  | 15/20 [02:35<00:54, 10.85s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.09it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.27it/s]
# Ensemble size 30 repetitions:  80%|████████  | 16/20 [02:46<00:43, 10.82s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.22it/s]
# Ensemble size 30 repetitions:  85%|████████▌ | 17/20 [02:57<00:32, 10.85s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.15it/s]
# Ensemble size 30 repetitions:  90%|█████████ | 18/20 [03:08<00:21, 10.96s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 32.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.37it/s]
# Ensemble size 30 repetitions:  95%|█████████▌| 19/20 [03:20<00:11, 11.08s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.95it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.26it/s]
# Ensemble size 30 repetitions: 100%|██████████| 20/20 [03:31<00:00, 10.58s/it]
# Ensemble size 100 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00,  9.65it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.63it/s]
# Ensemble size 100 repetitions:   5%|▌         | 1/20 [00:38<12:19, 38.93s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.69it/s]
# Ensemble size 100 repetitions:  10%|█         | 2/20 [01:23<12:38, 42.13s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.78it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.58it/s]
# Ensemble size 100 repetitions:  15%|█▌        | 3/20 [02:11<12:45, 45.05s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.23it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.53it/s]
# Ensemble size 100 repetitions:  20%|██        | 4/20 [02:58<12:11, 45.73s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.46it/s]
# Ensemble size 100 repetitions:  25%|██▌       | 5/20 [03:46<11:37, 46.53s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.76it/s]
# Ensemble size 100 repetitions:  30%|███       | 6/20 [04:35<11:04, 47.48s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.70it/s]
# Ensemble size 100 repetitions:  35%|███▌      | 7/20 [05:27<10:34, 48.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.58it/s]
# Ensemble size 100 repetitions:  40%|████      | 8/20 [06:19<09:59, 49.98s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.46it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.63it/s]
# Ensemble size 100 repetitions:  45%|████▌     | 9/20 [07:15<09:28, 51.65s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.55it/s]
# Ensemble size 100 repetitions:  50%|█████     | 10/20 [08:11<08:49, 52.98s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.79it/s]
# Ensemble size 100 repetitions:  55%|█████▌    | 11/20 [09:13<08:23, 55.94s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.01it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.81it/s]
# Ensemble size 100 repetitions:  60%|██████    | 12/20 [10:12<07:33, 56.64s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.17it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.58it/s]
# Ensemble size 100 repetitions:  65%|██████▌   | 13/20 [11:14<06:48, 58.33s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.27it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.56it/s]
# Ensemble size 100 repetitions:  70%|███████   | 14/20 [12:15<05:54, 59.14s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.27it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.62it/s]
# Ensemble size 100 repetitions:  75%|███████▌  | 15/20 [13:22<05:07, 61.50s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.07it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.87it/s]
# Ensemble size 100 repetitions:  80%|████████  | 16/20 [14:25<04:08, 62.03s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.08it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.70it/s]
# Ensemble size 100 repetitions:  85%|████████▌ | 17/20 [15:33<03:11, 63.84s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.21it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.60it/s]
# Ensemble size 100 repetitions:  90%|█████████ | 18/20 [16:39<02:09, 64.55s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.35it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.64it/s]
# Ensemble size 100 repetitions:  95%|█████████▌| 19/20 [17:52<01:06, 66.91s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.37it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.64it/s]
# Ensemble size 100 repetitions: 100%|██████████| 20/20 [19:00<00:00, 57.05s/it]

# %%
# print the elasticities
print(f"Model 1: a={elasticities[0][0]:.2f}, b={elasticities[0][1]:.2f}")
print(f"Model 2: a={elasticities[1][0]:.2f}, b={elasticities[1][1]:.2f}")
# Out:
# Model 1: a=7.12, b=-0.13
# Model 2: a=12.07, b=-0.17
