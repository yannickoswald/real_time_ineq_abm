# %%
#General packages
import os
import numpy as np
from tqdm import tqdm  ### package for progress bars
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
### MODEL 1 infrastructure
import pandas as pd
from model1_class import Model1
from run_enkf import *
### MODEL 2 infrastructure
from model2_class import Model2
#from run_both_models_n_times_and_compute_error import *


#%%
''' this experiment investigate the influence 
of the ensemble size on the ENKF performance '''

##### for this experiment change the test period to a much shorter one
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Assuming 'prepare_enkf', 'prepare_enkf2', 'run_enkf', and 'run_enkf2' are defined elsewhere

class Enkf_experiment3:
    
    def __init__(self, num_agents, macro_state_dim, repetitions, ensemble_sizes):
        self.num_agents = num_agents
        self.macro_state_dim = macro_state_dim
        self.repetitions = repetitions
        self.ensemble_sizes = ensemble_sizes
        self.results = []
        
    def run_experiment(self, start_year, end_year):
        
        model_params1 = {"population_size": 100,
         "growth_rate": 0.025,
         "b_begin": 1.3,
         "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
         "start_year": start_year,
         "uncertainty_para": 0}
        
        
        model_params2 = {"population_size": 100, 
                "concavity": 1,
                "growth_rate": 0.025, 
                "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
                "start_year": start_year,
                "adaptive_sensitivity": 0.02,
                "uncertainty_para": 0}

        
        for size in self.ensemble_sizes:
            array_of_results_enkf1 = np.zeros((self.repetitions, 1))
            array_of_results_enkf2 = np.zeros((self.repetitions, 1))
            for i in tqdm(range(self.repetitions), desc=f"Ensemble size {size} repetitions"):
                enkf1 = prepare_enkf(Model1,
                                          model_params= model_params1,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                enkf2 = prepare_enkf(Model2, model_params= model_params2,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                
                run_enkf(enkf1, start_year=start_year,end_year=end_year, filter_freq = 10)
                run_enkf(enkf2,  start_year=start_year,end_year=end_year, filter_freq = 10)
                array_of_results_enkf1[i, 0] = enkf1.integral_error()
                array_of_results_enkf2[i, 0] = enkf2.integral_error()
                
            self.results.append([f'Ensemble size {size}', array_of_results_enkf1, array_of_results_enkf2])
    
    def plot_results(self, save_fig=False, fig_name='fig7.png'):
        fig, ax = plt.subplots()
        boxplot_artists = []
        positions = np.arange(len(self.results)) * 2
        max_value = -np.inf  # Start with the smallest possible value

        for i, (label, array1, array2) in enumerate(self.results):
            pos = positions[i] + np.array([-0.4, 0.4])
            box1 = ax.boxplot(array1, positions=[pos[0]], widths=0.6, patch_artist=True)
            box2 = ax.boxplot(array2, positions=[pos[1]], widths=0.6, patch_artist=True)
            plt.setp(box1["boxes"], facecolor='lightcoral')
            plt.setp(box1["medians"], color='black')
            plt.setp(box2["boxes"], facecolor='lightblue')
            plt.setp(box2["medians"], color='black')

            # Calculate coefficient of variation
            cv1 = np.std(array1) / np.mean(array1)
            cv2 = np.std(array2) / np.mean(array2)

            # Annotate coefficient of variation below the boxplots
            y_offset = min(np.min(array1), np.min(array2)) - (0.05 * np.abs(min(np.min(array1), np.min(array2))))
            ax.text(pos[0], y_offset, f'CV: {cv1:.2f}', ha='center', va='top', fontsize=8)
            ax.text(pos[1], y_offset, f'CV: {cv2:.2f}', ha='center', va='top', fontsize=8)

            ax.plot(np.random.normal(pos[0], 0.04, size=len(array1)), array1, 'r.', alpha=0.7)
            ax.plot(np.random.normal(pos[1], 0.04, size=len(array2)), array2, 'b.', alpha=0.7)
            if i == 0:
                boxplot_artists.append(box1['boxes'][0])
                boxplot_artists.append(box2['boxes'][0])

            # Update max_value if needed
            max_value = max(max_value, np.max(array1), np.max(array2))
                
        ax.set_xticks(positions)
        ax.set_xticklabels([label for label, _, _ in self.results])
        ax.set_ylabel('Error sum under curve of mean error', fontsize=12)
        legend_labels = ['Model1 ENKF Boxplot', 'Model 2 ENKF Boxplot']
        ax.legend(boxplot_artists, legend_labels, title='Legend', loc="upper right", frameon=False)

        # Set y-axis upper limit
        ax.set_ylim(2, max_value+0.5)  # Assuming 3.5 is the lower limit you want

        plt.tight_layout()
        if save_fig:
            plt.savefig(fig_name, dpi=300)
        plt.show()
        
    def compute_elasticity_fit(self):
    
        means1 = np.zeros((len(self.results), 1))
        means2 = np.zeros((len(self.results), 1))

        for idx, (label, array1, array2) in enumerate(self.results):
            means1[idx, 0] = np.mean(array1)
            means2[idx, 0] = np.mean(array2)

        # Transform to log space for linear regression
        log_means1 = np.log(means1)
        log_means2 = np.log(means2)
        log_ensemble_sizes = np.log(self.ensemble_sizes)

        # Perform the linear regression in log space
        # The slope will be the exponent b and the intercept will be log(a)
        slope1, intercept1 = np.polyfit(log_ensemble_sizes, log_means1.ravel(), 1)
        slope2, intercept2 = np.polyfit(log_ensemble_sizes, log_means2.ravel(), 1)

        # Convert intercept into the coefficient a in the original space
        a1 = np.exp(intercept1)
        a2 = np.exp(intercept2)
        
        # Return the coefficients (a, b) for both fits
        return (a1, slope1), (a2, slope2)

# To use the class
num_agents = 100
start_year = 2007
end_year = 2009
macro_state_dim = 4
repetitions = 20
ensemble_sizes = [5,10,30,100]

experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
experiment.run_experiment(start_year=start_year, end_year=end_year)
experiment.plot_results(save_fig=True)
elasticities = experiment.compute_elasticity_fit()
# Out:
# Ensemble size 5 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 179.96it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 112.64it/s]
# Ensemble size 5 repetitions:   5%|▌         | 1/20 [00:01<00:24,  1.28s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 203.30it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 107.24it/s]
# Ensemble size 5 repetitions:  10%|█         | 2/20 [00:02<00:24,  1.34s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 179.32it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 114.36it/s]
# Ensemble size 5 repetitions:  15%|█▌        | 3/20 [00:03<00:22,  1.31s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 135.66it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 114.43it/s]
# Ensemble size 5 repetitions:  20%|██        | 4/20 [00:05<00:20,  1.31s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 195.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 119.41it/s]
# Ensemble size 5 repetitions:  25%|██▌       | 5/20 [00:06<00:19,  1.28s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 198.33it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 114.88it/s]
# Ensemble size 5 repetitions:  30%|███       | 6/20 [00:07<00:17,  1.26s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 143.90it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 119.37it/s]
# Ensemble size 5 repetitions:  35%|███▌      | 7/20 [00:08<00:16,  1.27s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 197.24it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 120.60it/s]
# Ensemble size 5 repetitions:  40%|████      | 8/20 [00:10<00:15,  1.26s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 198.35it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 119.01it/s]
# Ensemble size 5 repetitions:  45%|████▌     | 9/20 [00:11<00:13,  1.24s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 194.59it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 116.13it/s]
# Ensemble size 5 repetitions:  50%|█████     | 10/20 [00:12<00:12,  1.24s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 136.88it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 113.94it/s]
# Ensemble size 5 repetitions:  55%|█████▌    | 11/20 [00:13<00:11,  1.27s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 180.17it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 118.63it/s]
# Ensemble size 5 repetitions:  60%|██████    | 12/20 [00:15<00:10,  1.26s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 181.70it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 120.01it/s]
# Ensemble size 5 repetitions:  65%|██████▌   | 13/20 [00:16<00:08,  1.26s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 133.21it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 111.42it/s]
# Ensemble size 5 repetitions:  70%|███████   | 14/20 [00:17<00:07,  1.28s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 198.46it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 113.96it/s]
# Ensemble size 5 repetitions:  75%|███████▌  | 15/20 [00:19<00:06,  1.27s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 184.11it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 119.77it/s]
# Ensemble size 5 repetitions:  80%|████████  | 16/20 [00:20<00:05,  1.27s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 196.15it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 111.40it/s]
# Ensemble size 5 repetitions:  85%|████████▌ | 17/20 [00:21<00:03,  1.29s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 125.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 118.23it/s]
# Ensemble size 5 repetitions:  90%|█████████ | 18/20 [00:23<00:02,  1.32s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 187.89it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 115.57it/s]
# Ensemble size 5 repetitions:  95%|█████████▌| 19/20 [00:24<00:01,  1.31s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 192.00it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 117.26it/s]
# Ensemble size 5 repetitions: 100%|██████████| 20/20 [00:25<00:00,  1.28s/it]
# Ensemble size 10 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 85.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 60.76it/s]
# Ensemble size 10 repetitions:   5%|▌         | 1/20 [00:02<00:48,  2.54s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 104.96it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.01it/s]
# Ensemble size 10 repetitions:  10%|█         | 2/20 [00:04<00:44,  2.48s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 81.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.70it/s]
# Ensemble size 10 repetitions:  15%|█▌        | 3/20 [00:07<00:42,  2.52s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 100.73it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 62.53it/s]
# Ensemble size 10 repetitions:  20%|██        | 4/20 [00:09<00:39,  2.49s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 102.92it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 63.41it/s]
# Ensemble size 10 repetitions:  25%|██▌       | 5/20 [00:12<00:37,  2.52s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 82.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 62.32it/s]
# Ensemble size 10 repetitions:  30%|███       | 6/20 [00:15<00:35,  2.54s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 102.51it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.70it/s]
# Ensemble size 10 repetitions:  35%|███▌      | 7/20 [00:17<00:32,  2.52s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 80.09it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.88it/s]
# Ensemble size 10 repetitions:  40%|████      | 8/20 [00:20<00:30,  2.55s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 98.19it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 60.91it/s]
# Ensemble size 10 repetitions:  45%|████▌     | 9/20 [00:22<00:27,  2.53s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 83.23it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 59.60it/s]
# Ensemble size 10 repetitions:  50%|█████     | 10/20 [00:25<00:25,  2.56s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 104.19it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.33it/s]
# Ensemble size 10 repetitions:  55%|█████▌    | 11/20 [00:27<00:22,  2.55s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 83.14it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 59.69it/s]
# Ensemble size 10 repetitions:  60%|██████    | 12/20 [00:30<00:20,  2.60s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 107.89it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.71it/s]
# Ensemble size 10 repetitions:  65%|██████▌   | 13/20 [00:33<00:18,  2.58s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 105.20it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 63.50it/s]
# Ensemble size 10 repetitions:  70%|███████   | 14/20 [00:35<00:15,  2.62s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 83.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.74it/s]
# Ensemble size 10 repetitions:  75%|███████▌  | 15/20 [00:38<00:13,  2.62s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 102.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 63.80it/s]
# Ensemble size 10 repetitions:  80%|████████  | 16/20 [00:40<00:10,  2.60s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 79.68it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 63.73it/s]
# Ensemble size 10 repetitions:  85%|████████▌ | 17/20 [00:43<00:07,  2.65s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 102.89it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 62.35it/s]
# Ensemble size 10 repetitions:  90%|█████████ | 18/20 [00:46<00:05,  2.63s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 83.11it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 62.87it/s]
# Ensemble size 10 repetitions:  95%|█████████▌| 19/20 [00:49<00:02,  2.66s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:00<00:00, 107.04it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:00<00:00, 61.96it/s]
# Ensemble size 10 repetitions: 100%|██████████| 20/20 [00:51<00:00,  2.59s/it]
# Ensemble size 30 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 35.01it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.36it/s]
# Ensemble size 30 repetitions:   5%|▌         | 1/20 [00:07<02:31,  7.97s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 33.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.36it/s]
# Ensemble size 30 repetitions:  10%|█         | 2/20 [00:16<02:26,  8.13s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 33.23it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.97it/s]
# Ensemble size 30 repetitions:  15%|█▌        | 3/20 [00:24<02:19,  8.23s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 30.67it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.59it/s]
# Ensemble size 30 repetitions:  20%|██        | 4/20 [00:33<02:13,  8.37s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.92it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.19it/s]
# Ensemble size 30 repetitions:  25%|██▌       | 5/20 [00:41<02:06,  8.42s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 34.47it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.59it/s]
# Ensemble size 30 repetitions:  30%|███       | 6/20 [00:50<01:59,  8.54s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.68it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.22it/s]
# Ensemble size 30 repetitions:  35%|███▌      | 7/20 [00:59<01:51,  8.61s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.70it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.42it/s]
# Ensemble size 30 repetitions:  40%|████      | 8/20 [01:08<01:45,  8.75s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.32it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.08it/s]
# Ensemble size 30 repetitions:  45%|████▌     | 9/20 [01:17<01:38,  8.93s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 31.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.86it/s]
# Ensemble size 30 repetitions:  50%|█████     | 10/20 [01:26<01:30,  9.03s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 30.86it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.58it/s]
# Ensemble size 30 repetitions:  55%|█████▌    | 11/20 [01:36<01:22,  9.12s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.97it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.09it/s]
# Ensemble size 30 repetitions:  60%|██████    | 12/20 [01:45<01:13,  9.21s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 34.78it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.33it/s]
# Ensemble size 30 repetitions:  65%|██████▌   | 13/20 [01:55<01:06,  9.49s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 28.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.10it/s]
# Ensemble size 30 repetitions:  70%|███████   | 14/20 [02:05<00:57,  9.59s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.45it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.38it/s]
# Ensemble size 30 repetitions:  75%|███████▌  | 15/20 [02:15<00:48,  9.67s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 32.01it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 19.83it/s]
# Ensemble size 30 repetitions:  80%|████████  | 16/20 [02:25<00:39,  9.83s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 31.93it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 21.07it/s]
# Ensemble size 30 repetitions:  85%|████████▌ | 17/20 [02:36<00:30, 10.07s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 30.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.06it/s]
# Ensemble size 30 repetitions:  90%|█████████ | 18/20 [02:47<00:20, 10.31s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 31.36it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.89it/s]
# Ensemble size 30 repetitions:  95%|█████████▌| 19/20 [02:57<00:10, 10.41s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:01<00:00, 33.61it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:01<00:00, 20.86it/s]
# Ensemble size 30 repetitions: 100%|██████████| 20/20 [03:08<00:00,  9.42s/it]
# Ensemble size 100 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00, 10.38it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.28it/s]
# Ensemble size 100 repetitions:   5%|▌         | 1/20 [00:35<11:07, 35.15s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.54it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.43it/s]
# Ensemble size 100 repetitions:  10%|█         | 2/20 [01:16<11:34, 38.59s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00, 10.37it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.52it/s]
# Ensemble size 100 repetitions:  15%|█▌        | 3/20 [01:59<11:35, 40.89s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00, 10.64it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.35it/s]
# Ensemble size 100 repetitions:  20%|██        | 4/20 [02:40<10:54, 40.92s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.52it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.49it/s]
# Ensemble size 100 repetitions:  25%|██▌       | 5/20 [03:23<10:23, 41.56s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.52it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.54it/s]
# Ensemble size 100 repetitions:  30%|███       | 6/20 [04:07<09:52, 42.34s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.38it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.43it/s]
# Ensemble size 100 repetitions:  35%|███▌      | 7/20 [04:54<09:32, 44.03s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.73it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.35it/s]
# Ensemble size 100 repetitions:  40%|████      | 8/20 [05:41<08:58, 44.89s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.68it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.41it/s]
# Ensemble size 100 repetitions:  45%|████▌     | 9/20 [06:31<08:30, 46.40s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.16it/s]
# Ensemble size 100 repetitions:  50%|█████     | 10/20 [07:20<07:52, 47.20s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.45it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.32it/s]
# Ensemble size 100 repetitions:  55%|█████▌    | 11/20 [08:12<07:18, 48.77s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.15it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.22it/s]
# Ensemble size 100 repetitions:  60%|██████    | 12/20 [09:07<06:45, 50.69s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.28it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.29it/s]
# Ensemble size 100 repetitions:  65%|██████▌   | 13/20 [10:03<06:06, 52.32s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.46it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.15it/s]
# Ensemble size 100 repetitions:  70%|███████   | 14/20 [10:59<05:20, 53.39s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.33it/s]
# Ensemble size 100 repetitions:  75%|███████▌  | 15/20 [11:58<04:35, 55.11s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00, 10.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.06it/s]
# Ensemble size 100 repetitions:  80%|████████  | 16/20 [12:57<03:45, 56.27s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.43it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.32it/s]
# Ensemble size 100 repetitions:  85%|████████▌ | 17/20 [13:56<02:51, 57.04s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00, 10.23it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.24it/s]
# Ensemble size 100 repetitions:  90%|█████████ | 18/20 [14:57<01:56, 58.15s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00, 10.05it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.21it/s]
# Ensemble size 100 repetitions:  95%|█████████▌| 19/20 [16:05<01:01, 61.10s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 36/36 [00:03<00:00,  9.35it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 36/36 [00:05<00:00,  6.33it/s]
# Ensemble size 100 repetitions: 100%|██████████| 20/20 [17:09<00:00, 51.46s/it]

# %%
# print the elasticities
print(f"Model 1: a={elasticities[0][0]:.2f}, b={elasticities[0][1]:.2f}")
print(f"Model 2: a={elasticities[1][0]:.2f}, b={elasticities[1][1]:.2f}")
# Out:
# Model 1: a=11.29, b=-0.17
# Model 2: a=15.64, b=-0.21
