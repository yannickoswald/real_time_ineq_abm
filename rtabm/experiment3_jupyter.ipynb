# %%
#General packages
import os
import numpy as np
from tqdm import tqdm  ### package for progress bars
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
### MODEL 1 infrastructure
import pandas as pd
from model1_class import Model1
from run_enkf import *
### MODEL 2 infrastructure
from model2_class import Model2
#from run_both_models_n_times_and_compute_error import *


#%%
''' this experiment investigate the influence 
of the ensemble size on the ENKF performance '''

##### for this experiment change the test period to a much shorter one
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Assuming 'prepare_enkf', 'prepare_enkf2', 'run_enkf', and 'run_enkf2' are defined elsewhere

class Enkf_experiment3:
    
    def __init__(self, num_agents, macro_state_dim, repetitions, ensemble_sizes):
        self.num_agents = num_agents
        self.macro_state_dim = macro_state_dim
        self.repetitions = repetitions
        self.ensemble_sizes = ensemble_sizes
        self.results = []
        
    def run_experiment(self, start_year, end_year):
        
        model_params1 = {"population_size": 100,
         "growth_rate": 0.025,
         "b_begin": 1.3,
         "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
         "start_year": start_year,
         "uncertainty_para": 0}
        
        
        model_params2 = {"population_size": 100, 
                "concavity": 1,
                "growth_rate": 0.025, 
                "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
                "start_year": start_year,
                "adaptive_sensitivity": 0.02,
                "uncertainty_para": 0}

        
        for size in self.ensemble_sizes:
            array_of_results_enkf1 = np.zeros((self.repetitions, 1))
            array_of_results_enkf2 = np.zeros((self.repetitions, 1))
            for i in tqdm(range(self.repetitions), desc=f"Ensemble size {size} repetitions"):
                enkf1 = prepare_enkf(Model1,
                                          model_params= model_params1,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                enkf2 = prepare_enkf(Model2, model_params= model_params2,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                
                run_enkf(enkf1, start_year=start_year,end_year=end_year, filter_freq = 10)
                run_enkf(enkf2,  start_year=start_year,end_year=end_year, filter_freq = 10)
                array_of_results_enkf1[i, 0] = enkf1.integral_error()
                array_of_results_enkf2[i, 0] = enkf2.integral_error()
                
            self.results.append([f'Ensemble size {size}', array_of_results_enkf1, array_of_results_enkf2])
    
    def plot_results(self, save_fig=False, fig_name='fig7.png'):
        fig, ax = plt.subplots()
        boxplot_artists = []
        positions = np.arange(len(self.results)) * 2
        max_value = -np.inf  # Start with the smallest possible value

        for i, (label, array1, array2) in enumerate(self.results):
            pos = positions[i] + np.array([-0.4, 0.4])
            box1 = ax.boxplot(array1, positions=[pos[0]], widths=0.6, patch_artist=True)
            box2 = ax.boxplot(array2, positions=[pos[1]], widths=0.6, patch_artist=True)
            plt.setp(box1["boxes"], facecolor='lightcoral')
            plt.setp(box1["medians"], color='black')
            plt.setp(box2["boxes"], facecolor='lightblue')
            plt.setp(box2["medians"], color='black')

            # Calculate coefficient of variation
            cv1 = np.std(array1) / np.mean(array1)
            cv2 = np.std(array2) / np.mean(array2)

            # Annotate coefficient of variation below the boxplots
            y_offset = min(np.min(array1), np.min(array2)) - (0.05 * np.abs(min(np.min(array1), np.min(array2))))
            ax.text(pos[0], y_offset, f'CV: {cv1:.2f}', ha='center', va='top', fontsize=8)
            ax.text(pos[1], y_offset, f'CV: {cv2:.2f}', ha='center', va='top', fontsize=8)

            ax.plot(np.random.normal(pos[0], 0.04, size=len(array1)), array1, 'r.', alpha=0.7)
            ax.plot(np.random.normal(pos[1], 0.04, size=len(array2)), array2, 'b.', alpha=0.7)
            if i == 0:
                boxplot_artists.append(box1['boxes'][0])
                boxplot_artists.append(box2['boxes'][0])

            # Update max_value if needed
            max_value = max(max_value, np.max(array1), np.max(array2))
                
        ax.set_xticks(positions)
        ax.set_xticklabels([label for label, _, _ in self.results])
        ax.set_ylabel('Error sum under curve of mean error', fontsize=12)
        legend_labels = ['Model 1 ENKF Boxplot', 'Model 2 ENKF Boxplot']
        ax.legend(boxplot_artists, legend_labels, title='Legend', loc="upper right", frameon=False)

        # Set y-axis upper limit
        ax.set_ylim(2, max_value+0.5)  # Assuming 3.5 is the lower limit you want

        plt.tight_layout()
        if save_fig:
            plt.savefig(fig_name, dpi=300)
        plt.show()
        
    def compute_elasticity_fit(self):
    
        means1 = np.zeros((len(self.results), 1))
        means2 = np.zeros((len(self.results), 1))

        for idx, (label, array1, array2) in enumerate(self.results):
            means1[idx, 0] = np.mean(array1)
            means2[idx, 0] = np.mean(array2)

        # Transform to log space for linear regression
        log_means1 = np.log(means1)
        log_means2 = np.log(means2)
        log_ensemble_sizes = np.log(self.ensemble_sizes)

        # Perform the linear regression in log space
        # The slope will be the exponent b and the intercept will be log(a)
        slope1, intercept1 = np.polyfit(log_ensemble_sizes, log_means1.ravel(), 1)
        slope2, intercept2 = np.polyfit(log_ensemble_sizes, log_means2.ravel(), 1)

        # Convert intercept into the coefficient a in the original space
        a1 = np.exp(intercept1)
        a2 = np.exp(intercept2)
        
        # Return the coefficients (a, b) for both fits
        return (a1, slope1), (a2, slope2)

# To use the class
num_agents = 100
start_year = 1990
end_year = 1993
macro_state_dim = 4
repetitions = 20
ensemble_sizes = [5,10,30,100]

experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
experiment.run_experiment(start_year=start_year, end_year=end_year)
experiment.plot_results(save_fig=True)
elasticities = experiment.compute_elasticity_fit()
# Out:
# Ensemble size 5 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 188.02it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 122.36it/s]
# Ensemble size 5 repetitions:   5%|▌         | 1/20 [00:01<00:26,  1.42s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 188.02it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 123.53it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 144.29it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 121.05it/s]
# Ensemble size 5 repetitions:  15%|█▌        | 3/20 [00:04<00:24,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 179.89it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 115.17it/s]
# Ensemble size 5 repetitions:  20%|██        | 4/20 [00:05<00:22,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 184.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 120.00it/s]
# Ensemble size 5 repetitions:  25%|██▌       | 5/20 [00:07<00:21,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 139.53it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 120.45it/s]
# Ensemble size 5 repetitions:  30%|███       | 6/20 [00:08<00:20,  1.46s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 194.67it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.24it/s]
# Ensemble size 5 repetitions:  35%|███▌      | 7/20 [00:10<00:18,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 189.03it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 101.09it/s]
# Ensemble size 5 repetitions:  40%|████      | 8/20 [00:11<00:17,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 185.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 121.37it/s]
# Ensemble size 5 repetitions:  45%|████▌     | 9/20 [00:12<00:15,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 189.84it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.80it/s]
# Ensemble size 5 repetitions:  50%|█████     | 10/20 [00:14<00:14,  1.41s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 141.39it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 121.88it/s]
# Ensemble size 5 repetitions:  55%|█████▌    | 11/20 [00:15<00:12,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 190.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.37it/s]
# Ensemble size 5 repetitions:  60%|██████    | 12/20 [00:17<00:11,  1.42s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 189.52it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 111.50it/s]
# Ensemble size 5 repetitions:  65%|██████▌   | 13/20 [00:18<00:09,  1.41s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 140.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 115.01it/s]
# Ensemble size 5 repetitions:  70%|███████   | 14/20 [00:20<00:08,  1.46s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 184.26it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 121.37it/s]
# Ensemble size 5 repetitions:  75%|███████▌  | 15/20 [00:21<00:07,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 186.95it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 121.52it/s]
# Ensemble size 5 repetitions:  80%|████████  | 16/20 [00:22<00:05,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 184.92it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 126.35it/s]
# Ensemble size 5 repetitions:  85%|████████▌ | 17/20 [00:24<00:04,  1.44s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 187.05it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 125.18it/s]
# Ensemble size 5 repetitions:  90%|█████████ | 18/20 [00:25<00:02,  1.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 147.95it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 119.03it/s]
# Ensemble size 5 repetitions:  95%|█████████▌| 19/20 [00:27<00:01,  1.45s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 185.70it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 118.96it/s]
# Ensemble size 5 repetitions: 100%|██████████| 20/20 [00:28<00:00,  1.43s/it]
# Ensemble size 10 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 86.80it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.79it/s]
# Ensemble size 10 repetitions:   5%|▌         | 1/20 [00:02<00:52,  2.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 104.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 65.57it/s]
# Ensemble size 10 repetitions:  10%|█         | 2/20 [00:05<00:48,  2.71s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 87.30it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 66.98it/s]
# Ensemble size 10 repetitions:  15%|█▌        | 3/20 [00:08<00:46,  2.75s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 87.28it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 63.45it/s]
# Ensemble size 10 repetitions:  20%|██        | 4/20 [00:11<00:44,  2.77s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 99.79it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 63.36it/s]
# Ensemble size 10 repetitions:  25%|██▌       | 5/20 [00:13<00:41,  2.75s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 101.48it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.24it/s]
# Ensemble size 10 repetitions:  30%|███       | 6/20 [00:16<00:38,  2.77s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 86.57it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 61.94it/s]
# Ensemble size 10 repetitions:  35%|███▌      | 7/20 [00:19<00:36,  2.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 85.94it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.30it/s]
# Ensemble size 10 repetitions:  40%|████      | 8/20 [00:22<00:33,  2.79s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 101.37it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 62.66it/s]
# Ensemble size 10 repetitions:  45%|████▌     | 9/20 [00:24<00:30,  2.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 81.84it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 63.83it/s]
# Ensemble size 10 repetitions:  50%|█████     | 10/20 [00:27<00:28,  2.82s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 87.52it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.34it/s]
# Ensemble size 10 repetitions:  55%|█████▌    | 11/20 [00:30<00:25,  2.83s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 102.05it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.08it/s]
# Ensemble size 10 repetitions:  60%|██████    | 12/20 [00:33<00:22,  2.80s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 84.12it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 64.83it/s]
# Ensemble size 10 repetitions:  65%|██████▌   | 13/20 [00:36<00:19,  2.84s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 86.78it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 62.75it/s]
# Ensemble size 10 repetitions:  70%|███████   | 14/20 [00:39<00:17,  2.85s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 100.94it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 57.21it/s]
# Ensemble size 10 repetitions:  75%|███████▌  | 15/20 [00:42<00:14,  2.86s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 100.00it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 61.98it/s]
# Ensemble size 10 repetitions:  80%|████████  | 16/20 [00:45<00:11,  2.88s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 81.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 66.53it/s]
# Ensemble size 10 repetitions:  85%|████████▌ | 17/20 [00:48<00:08,  2.91s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 87.03it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 65.88it/s]
# Ensemble size 10 repetitions:  90%|█████████ | 18/20 [00:50<00:05,  2.91s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 99.79it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 62.58it/s]
# Ensemble size 10 repetitions:  95%|█████████▌| 19/20 [00:53<00:02,  2.91s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 79.97it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 62.62it/s]
# Ensemble size 10 repetitions: 100%|██████████| 20/20 [00:56<00:00,  2.85s/it]
# Ensemble size 30 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.59it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.31it/s]
# Ensemble size 30 repetitions:   5%|▌         | 1/20 [00:08<02:47,  8.81s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.11it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.52it/s]
# Ensemble size 30 repetitions:  10%|█         | 2/20 [00:18<02:43,  9.11s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.63it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.51it/s]
# Ensemble size 30 repetitions:  15%|█▌        | 3/20 [00:27<02:36,  9.21s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.19it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.31it/s]
# Ensemble size 30 repetitions:  20%|██        | 4/20 [00:36<02:28,  9.30s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.48it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.15it/s]
# Ensemble size 30 repetitions:  25%|██▌       | 5/20 [00:46<02:20,  9.38s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.79it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.66it/s]
# Ensemble size 30 repetitions:  30%|███       | 6/20 [00:55<02:12,  9.43s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.40it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.44it/s]
# Ensemble size 30 repetitions:  35%|███▌      | 7/20 [01:05<02:03,  9.49s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 35.12it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 22.09it/s]
# Ensemble size 30 repetitions:  40%|████      | 8/20 [01:15<01:53,  9.49s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.90it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.83it/s]
# Ensemble size 30 repetitions:  45%|████▌     | 9/20 [01:25<01:46,  9.68s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.02it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.97it/s]
# Ensemble size 30 repetitions:  50%|█████     | 10/20 [01:35<01:37,  9.78s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.61it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.44it/s]
# Ensemble size 30 repetitions:  55%|█████▌    | 11/20 [01:45<01:28,  9.89s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.79it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.90it/s]
# Ensemble size 30 repetitions:  60%|██████    | 12/20 [01:55<01:19,  9.95s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.93it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.66it/s]
# Ensemble size 30 repetitions:  65%|██████▌   | 13/20 [02:06<01:11, 10.16s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.60it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.95it/s]
# Ensemble size 30 repetitions:  70%|███████   | 14/20 [02:16<01:01, 10.26s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.97it/s]
# Ensemble size 30 repetitions:  75%|███████▌  | 15/20 [02:27<00:51, 10.35s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.78it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.22it/s]
# Ensemble size 30 repetitions:  80%|████████  | 16/20 [02:37<00:41, 10.46s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.71it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 20.86it/s]
# Ensemble size 30 repetitions:  85%|████████▌ | 17/20 [02:49<00:32, 10.92s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.70it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.54it/s]
# Ensemble size 30 repetitions:  90%|█████████ | 18/20 [03:01<00:22, 11.24s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 33.84it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.59it/s]
# Ensemble size 30 repetitions:  95%|█████████▌| 19/20 [03:12<00:11, 11.18s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 34.05it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 21.69it/s]
# Ensemble size 30 repetitions: 100%|██████████| 20/20 [03:23<00:00, 10.19s/it]
# Ensemble size 100 repetitions:   0%|          | 0/20 [00:00<?, ?it/s]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:07<00:00,  6.73it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:26<00:00,  1.79it/s]
# Ensemble size 100 repetitions:   5%|▌         | 1/20 [01:00<19:11, 60.63s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:13<00:00,  3.50it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:26<00:00,  1.79it/s]
# Ensemble size 100 repetitions:  10%|█         | 2/20 [03:03<29:09, 97.22s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:12<00:00,  3.76it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:26<00:00,  1.81it/s]
# Ensemble size 100 repetitions:  15%|█▌        | 3/20 [05:02<30:19, 107.04s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.34it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.80it/s]
# Ensemble size 100 repetitions:  20%|██        | 4/20 [06:11<24:33, 92.09s/it] c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.18it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.71it/s]
# Ensemble size 100 repetitions:  25%|██▌       | 5/20 [06:57<18:52, 75.47s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.11it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.82it/s]
# Ensemble size 100 repetitions:  30%|███       | 6/20 [07:43<15:16, 65.49s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.21it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.80it/s]
# Ensemble size 100 repetitions:  35%|███▌      | 7/20 [08:29<12:47, 59.01s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.27it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.68it/s]
# Ensemble size 100 repetitions:  40%|████      | 8/20 [09:22<11:26, 57.20s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.16it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.86it/s]
# Ensemble size 100 repetitions:  45%|████▌     | 9/20 [10:17<10:22, 56.55s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.40it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.85it/s]
# Ensemble size 100 repetitions:  50%|█████     | 10/20 [11:12<09:21, 56.16s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.85it/s]
# Ensemble size 100 repetitions:  55%|█████▌    | 11/20 [12:05<08:15, 55.09s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.53it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.89it/s]
# Ensemble size 100 repetitions:  60%|██████    | 12/20 [13:04<07:31, 56.38s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.27it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.85it/s]
# Ensemble size 100 repetitions:  65%|██████▌   | 13/20 [14:05<06:43, 57.60s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.46it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.89it/s]
# Ensemble size 100 repetitions:  70%|███████   | 14/20 [15:06<05:51, 58.56s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.01it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.92it/s]
# Ensemble size 100 repetitions:  75%|███████▌  | 15/20 [16:06<04:55, 59.17s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.91it/s]
# Ensemble size 100 repetitions:  80%|████████  | 16/20 [17:09<04:00, 60.24s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.07it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.83it/s]
# Ensemble size 100 repetitions:  85%|████████▌ | 17/20 [18:12<03:03, 61.25s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.17it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.87it/s]
# Ensemble size 100 repetitions:  90%|█████████ | 18/20 [19:16<02:03, 61.93s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:04<00:00, 10.35it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:06<00:00,  6.92it/s]
# Ensemble size 100 repetitions:  95%|█████████▌| 19/20 [20:18<01:02, 62.06s/it]c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# c:\Users\yoswald\Dropbox\Arbeit\postdoc_leeds\real_time_ineq_abm\rtabm\agent1_class.py:58: RuntimeWarning: divide by zero encountered in scalar divide
#   self.g_rate = (self.wealth_list[-1] / self.wealth_list[-2]) - 1
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.41it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:07<00:00,  6.85it/s]
# Ensemble size 100 repetitions: 100%|██████████| 20/20 [21:30<00:00, 64.52s/it]

# %%
# print the elasticities
print(f"Model 1: a={elasticities[0][0]:.2f}, b={elasticities[0][1]:.2f}")
print(f"Model 2: a={elasticities[1][0]:.2f}, b={elasticities[1][1]:.2f}")
# Out:
# Model 1: a=7.96, b=-0.14
# Model 2: a=11.87, b=-0.15
