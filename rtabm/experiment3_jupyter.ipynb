# %%
#General packages
import os
import numpy as np
from tqdm import tqdm  ### package for progress bars
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
### MODEL 1 infrastructure
import pandas as pd
from model1_class import Model1
from run_enkf import *
### MODEL 2 infrastructure
from model2_class import Model2
#from run_both_models_n_times_and_compute_error import *


#%%
''' this experiment investigate the influence 
of the ensemble size on the ENKF performance '''

##### for this experiment change the test period to a much shorter one
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Assuming 'prepare_enkf', 'prepare_enkf2', 'run_enkf', and 'run_enkf2' are defined elsewhere

class Enkf_experiment3:
    
    def __init__(self, num_agents, macro_state_dim, repetitions, ensemble_sizes):
        self.num_agents = num_agents
        self.macro_state_dim = macro_state_dim
        self.repetitions = repetitions
        self.ensemble_sizes = ensemble_sizes
        self.results = []
        
    def run_experiment(self, start_year, end_year):
        
        model_params1 = {"population_size": 100,
         "growth_rate": 0.03,
         "b_begin": 1.3,
         "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
         "start_year": start_year,
         "uncertainty_para": 0}
        
        
        model_params2 = {"population_size": 100, 
                "concavity": 1,
                "growth_rate": 0.03, 
                "distribution": "exponential_pareto", # either "Pareto_lognormal" or "exponential_pareto"
                "start_year": start_year,
                "adaptive_sensitivity": 0.02,
                "uncertainty_para": 0}

        
        for size in self.ensemble_sizes:
            array_of_results_enkf1 = np.zeros((self.repetitions, 1))
            array_of_results_enkf2 = np.zeros((self.repetitions, 1))
            for i in tqdm(range(self.repetitions), desc=f"Ensemble size {size} repetitions"):
                enkf1 = prepare_enkf(Model1,
                                          model_params= model_params1,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                enkf2 = prepare_enkf(Model2, model_params= model_params2,
                                          ensemble_size = size,
                                          macro_state_dim = self.macro_state_dim,
                                          filter_freq = 10,
                                          uncertainty_obs = 0.05)
                
                run_enkf(enkf1, start_year=start_year,end_year=end_year, filter_freq = 10)
                run_enkf(enkf2,  start_year=start_year,end_year=end_year, filter_freq = 10)
                array_of_results_enkf1[i, 0] = enkf1.integral_error()
                array_of_results_enkf2[i, 0] = enkf2.integral_error()
                
            self.results.append([f'Ensemble size {size}', array_of_results_enkf1, array_of_results_enkf2])
    
    def plot_results(self, save_fig=False, fig_name='fig7.png'):
        fig, ax = plt.subplots()
        boxplot_artists = []
        positions = np.arange(len(self.results)) * 2
        max_value = -np.inf  # Start with the smallest possible value

        for i, (label, array1, array2) in enumerate(self.results):
            pos = positions[i] + np.array([-0.4, 0.4])
            box1 = ax.boxplot(array1, positions=[pos[0]], widths=0.6, patch_artist=True)
            box2 = ax.boxplot(array2, positions=[pos[1]], widths=0.6, patch_artist=True)
            plt.setp(box1["boxes"], facecolor='lightcoral')
            plt.setp(box1["medians"], color='black')
            plt.setp(box2["boxes"], facecolor='lightblue')
            plt.setp(box2["medians"], color='black')

            # Calculate coefficient of variation
            cv1 = np.std(array1) / np.mean(array1)
            cv2 = np.std(array2) / np.mean(array2)

            # Annotate coefficient of variation below the boxplots
            y_offset = min(np.min(array1), np.min(array2)) - (0.05 * np.abs(min(np.min(array1), np.min(array2))))
            ax.text(pos[0], y_offset, f'CV: {cv1:.2f}', ha='center', va='top', fontsize=8)
            ax.text(pos[1], y_offset, f'CV: {cv2:.2f}', ha='center', va='top', fontsize=8)

            ax.plot(np.random.normal(pos[0], 0.04, size=len(array1)), array1, 'r.', alpha=0.7)
            ax.plot(np.random.normal(pos[1], 0.04, size=len(array2)), array2, 'b.', alpha=0.7)
            if i == 0:
                boxplot_artists.append(box1['boxes'][0])
                boxplot_artists.append(box2['boxes'][0])

            # Update max_value if needed
            max_value = max(max_value, np.max(array1), np.max(array2))
                
        ax.set_xticks(positions)
        ax.set_xticklabels([label for label, _, _ in self.results])
        ax.set_ylabel('Error sum under curve of mean error', fontsize=12)
        legend_labels = ['Model 1 EnKF Boxplot', 'Model 2 EnKF Boxplot']
        ax.legend(boxplot_artists, legend_labels, title='Legend', loc="upper right", frameon=False)

        # Set y-axis upper limit
        ax.set_ylim(2, max_value+0.5)  # Assuming 3.5 is the lower limit you want

        plt.tight_layout()
        if save_fig:
            plt.savefig(fig_name, dpi=300)
        plt.show()
        
    def compute_elasticity_fit(self):
    
        means1 = np.zeros((len(self.results), 1))
        means2 = np.zeros((len(self.results), 1))

        for idx, (label, array1, array2) in enumerate(self.results):
            means1[idx, 0] = np.mean(array1)
            means2[idx, 0] = np.mean(array2)

        # Transform to log space for linear regression
        log_means1 = np.log(means1)
        log_means2 = np.log(means2)
        log_ensemble_sizes = np.log(self.ensemble_sizes)

        # Perform the linear regression in log space
        # The slope will be the exponent b and the intercept will be log(a)
        slope1, intercept1 = np.polyfit(log_ensemble_sizes, log_means1.ravel(), 1)
        slope2, intercept2 = np.polyfit(log_ensemble_sizes, log_means2.ravel(), 1)

        # Convert intercept into the coefficient a in the original space
        a1 = np.exp(intercept1)
        a2 = np.exp(intercept2)
        
        # Return the coefficients (a, b) for both fits
        return (a1, slope1), (a2, slope2)

# To use the class
num_agents = 100
start_year = 2019
end_year = 2022
macro_state_dim = 4
repetitions = 20
ensemble_sizes = [5,10,30,100]

experiment = Enkf_experiment3(num_agents, macro_state_dim, repetitions, ensemble_sizes)
experiment.run_experiment(start_year=start_year, end_year=end_year)
experiment.plot_results(save_fig=True)
elasticities = experiment.compute_elasticity_fit()
# Out:
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 183.13it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 76.44it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 42.00it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 16.28it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 50.17it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 16.75it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 41.63it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 16.66it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 45.22it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 16.94it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 65.44it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 18.51it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 42.18it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 16.73it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 50.21it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:02<00:00, 18.99it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 130.03it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 75.83it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 142.72it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 78.45it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 190.29it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 78.10it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 134.06it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 77.96it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 192.89it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 78.16it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 130.93it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 78.11it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 202.05it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 67.02it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 189.81it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 77.15it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 129.99it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 74.32it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 190.10it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 75.95it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 131.11it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 78.22it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 205.76it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:00<00:00, 75.81it/s]
# Ensemble size 5 repetitions: 100%|██████████| 20/20 [02:33<00:00,  7.68s/it]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 80.90it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.59it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 107.93it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.70it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 105.24it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 33.87it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 105.03it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 36.92it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 101.48it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 34.24it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 104.17it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.43it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 106.24it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.61it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 106.04it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.03it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 106.16it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 38.80it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 107.50it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.45it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 105.64it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.24it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 108.50it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 34.53it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 110.74it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 38.92it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 105.89it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 36.04it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 102.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.16it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 106.86it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 35.56it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 110.81it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 34.56it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 103.04it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 37.38it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 102.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 36.10it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:00<00:00, 106.66it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:01<00:00, 34.63it/s]
# Ensemble size 10 repetitions: 100%|██████████| 20/20 [02:31<00:00,  7.55s/it]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 31.65it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.80it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 28.76it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.97it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.09it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 13.05it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 28.79it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.48it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.25it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.96it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.09it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.86it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.21it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.51it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.04it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.32it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.32it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.38it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.64it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.73it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.61it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.69it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.56it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.71it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.20it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.70it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.30it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.69it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.39it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.31it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.64it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.32it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.47it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 30.42it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.80it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.51it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.85it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:01<00:00, 29.98it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:03<00:00, 12.55it/s]
# Ensemble size 30 repetitions: 100%|██████████| 20/20 [08:09<00:00, 24.48s/it]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.23it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.90it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.47it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.90it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.65it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.80it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.52it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.93it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.53it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.95it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.11it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.85it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.41it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.90it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.74it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.95it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.73it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.95it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.32it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.83it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.46it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.93it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.27it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.95it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.65it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.94it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.36it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.93it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.43it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.82it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.12it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.83it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  9.12it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.83it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.73it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.94it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.58it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.81it/s]
# Iterations ENKF <class 'model1_class.Model1'>: 100%|██████████| 48/48 [00:05<00:00,  8.39it/s]
# Iterations ENKF <class 'model2_class.Model2'>: 100%|██████████| 48/48 [00:12<00:00,  3.85it/s]
# Ensemble size 100 repetitions: 100%|██████████| 20/20 [39:06<00:00, 117.32s/it]

# %%
# print the elasticities
print(f"Model 1: a={elasticities[0][0]:.2f}, b={elasticities[0][1]:.2f}")
print(f"Model 2: a={elasticities[1][0]:.2f}, b={elasticities[1][1]:.2f}")
# Out:
# Model 1: a=16.53, b=-0.26
# Model 2: a=15.81, b=-0.19
